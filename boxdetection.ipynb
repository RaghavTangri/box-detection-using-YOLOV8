# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_PATH = "/content/drive/MyDrive/yolov8"

# %%
# %cd {ROOT_PATH}
# Out:
# /content/drive/MyDrive/yolov8

# %%
# !pwd
# Out:
# /content/drive/MyDrive/yolov8

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data='/content/drive/MyDrive/yolov8/box.v1i.yolov8/data.yaml' epochs=10 imgsz=640 save=true
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train3/weights/best.pt data=/content/drive/MyDrive/yolov8/box.v1i.yolov8/data.yaml
# Out:
# 2024-07-24 05:52:18.452782: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 05:52:18.452841: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 05:52:18.454541: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 05:52:18.463305: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !yolo task=segment mode=predict model=runs/segment/train3/weights/best.pt conf=0.25 source=/content/drive/MyDrive/yolov8/box.v1i.yolov8/test/images save=true
# Out:
# 2024-07-24 05:54:38.735609: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 05:54:38.735835: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 05:54:38.742160: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 05:54:38.764545: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/drive/MyDrive/yolov8/runs/segment/predict/*')[:3]:
  display(Image(filename=image_path, width=600))
  print("\n")

# %%
# !yolo task=segment mode=predict model=runs/segment/train3/weights/best.pt conf=0.25 source= '/content/drive/MyDrive/yolov8/video box.mp4' save=true
# Out:
# 2024-07-24 06:16:43.452920: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-24 06:16:43.452979: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-24 06:16:43.454707: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-24 06:16:43.464243: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from IPython.display import Video
display(Video('f/content/drive/MyDrive/yolov8/runs/segment/predict2/video box.mp4', embed=True))
# Out:
# <video controls  >
#  <source src="....mp4" type="None">
#  Your browser does not support the video tag.
#  </video>

# %%
}
